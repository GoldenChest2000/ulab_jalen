# %%
import pandas as pd

# %%
series1 = pd.Series(data, index=['a', 'b', 'c', 'd', 'e'])
print(series1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 series1 = pd.Series(data, index=['a', 'b', 'c', 'd', 'e'])
#       2 print(series1)
#
# NameError: name 'data' is not defined
