# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
def orbital_period(a):
    # Calculates orbital periods in the Solar System with Kepler's 3rd Law
    period = (a**3) ** 0.5
    return period

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
planet_a = 0.5
planet_b = 1
planet_c = 1.5

orbital_period(planet_a), orbital_period(planet_b), orbital_period(planet_c)
# Out:
# (0.3535533905932738, 1.0, 1.8371173070873836)

# %% [markdown]
# Import `numpy` in the cell below.

# %%
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# Just once. After you do, it remains active until the kernel turns off.

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
def orbital_period_numpy(a):
    # Calculates orbital periods in the Solar System with Kepler's 3rd Law using numpy's square root function
    period = np.sqrt(a**3)
    return period

# %% [markdown]
# Import the `time` package in the cell below.

# %%
import time

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
a = 5
orbital_period(a), orbital_period_numpy(a)

start = time.time()
orbital_period(a)
end = time.time()
print(f"Standard function took {end - start:.6f} seconds")

start = time.time()
orbital_period_numpy(a)
end = time.time()
print(f"Numpy function took {end - start:.6f} seconds")
# Out:
# Standard function took 0.000000 seconds
# Numpy function took 0.000506 seconds

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# The original function is slightly faster than the numpy one. It is faster because it is less precise. As a result, for more complex functions, numpy would presumably be better.

# %% [markdown]
# Define a **list** in the cell below that contains a least 1000 semi-major axis values with a **for** loop.

# %%
semimajor_axes = [i * 0.01 for i in range(1, 1001)]
semi_major_array = np.array(semimajor_axes)

# %% [markdown]
# Time each of your functions again with this new list.

# %%
# Had to turn it into an array, list gives an error

start = time.time()
orbital_period(semi_major_array)
end = time.time()
print(f"Standard function took {end - start:.6f} seconds")

start = time.time()
orbital_period_numpy(semi_major_array)
end = time.time()
print(f"Numpy function took {end - start:.6f} seconds")
# Out:
# Standard function took 0.000000 seconds
# Numpy function took 0.001003 seconds

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Standard function is faster. Same reason as last time?

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

below_350K = [radii[i] for i in range(len(temperatures)) if temperatures[i] < 350]
print("Radii of planets with temperatures less than 350 Kelvin:", below_350K)
# Out:
# Radii of planets with temperatures less than 350 Kelvin: [1.2, 2.0]

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
first_three_radii = radii[:3]
print("The first three planet radii are", first_three_radii)
# Out:
# The first three planet radii are [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
planet_names = ["Hoth", "Alderaan", "Corsucant", "Dagobah", "Genosis", "Tatooine"]

planet_data = {planet_names[i]: {"radius": radii[i], "temperature": temperatures[i]} for i in range(len(radii))}
print("\nStar Wars Dictionary:")
print(planet_data)
# Out:
# Star Wars Dictionary:
# {'Hoth': {'radius': 1.2, 'temperature': 300}, 'Alderaan': {'radius': 0.8, 'temperature': 400}, 'Corsucant': {'radius': 1.5, 'temperature': 350}, 'Dagobah': {'radius': 2.0, 'temperature': 280}, 'Genosis': {'radius': 1.0, 'temperature': 500}, 'Tatooine': {'radius': 0.6, 'temperature': 450}}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
# Done

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
filtered_planets = {name: data for name, data in planet_data.items() if 1.0 <= data["radius"] <= 2.0}
print("\nPlanets between 1 and 2 Re:")
print(filtered_planets)
# Out:
# Planets between 1 and 2 Re:
# {'Hoth': {'radius': 1.2, 'temperature': 300}, 'Corsucant': {'radius': 1.5, 'temperature': 350}, 'Dagobah': {'radius': 2.0, 'temperature': 280}, 'Genosis': {'radius': 1.0, 'temperature': 500}}

# %% [markdown]
# ## 3 NumPy
# With your 1,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
semi_major_array = np.array(semimajor_axes)

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
np.mean(semi_major_array), np.min(semi_major_array), np.max(semi_major_array)
# Out:
# (5.005, 0.01, 10.0)

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
np.std(semi_major_array)

# Takes the standard deviation of the array distribution
# Out:
# 2.886749902572095

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
# Two entries --> multi-dimensional
planet_data_array = np.array([radii, temperatures])
print("Two-Dimensional Array:\n", planet_data_array)
# Out:
# Two-Dimensional Array:
#  [[  1.2   0.8   1.5   2.    1.    0.6]
#  [300.  400.  350.  280.  500.  450. ]]

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
for i in range(len(planet_data_array)):  # Loop through rows
    for j in range(len(planet_data_array[i])):  # Looping through columns
        if i == 1 and j == 2:  # Second row (index 1), third column (index 2)
            print("Value with for loop:", planet_data_array[i][j])
# Out:
# Value with for loop: 350.0

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
value_numpy = planet_data_array[1, 2]
print("Value using NumPy array indexing:", value_numpy)
# Out:
# Value using NumPy array indexing: 350.0

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
# T = a^(3/2)

import matplotlib.pyplot as plt

semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
orbital_periods = [0.35, 1, 2.83, 1.84, 1.31, 0.72]

plt.scatter(semi_major_axes, orbital_periods)
plt.xlabel("Semi-Major Axes (megameters)")
plt.ylabel('Orbital Periods (years)')
plt.title('Orbital Periods of Exoplanets')
plt.legend(loc="lower right")

# The legend doesn't show anything as there's only one 'line' on the graph
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]

plt.bar(radii, temperatures)
plt.xlabel("Radii (10^6 m)")
plt.ylabel("Temperature (K)")
plt.title("Equilibrium Temperatures vs. Radii")
plt.legend(loc="upper right")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# 1 row, 2 columns with the scatter plot on the left and the bar graph on the right.

# Bar graph
axes[0].bar(radii, temperatures, color='b', alpha=0.7, edgecolor='black')
axes[0].set_xlabel("Radii (10^6 m)")
axes[0].set_ylabel("Temperature (K)")
axes[0].set_title("Equilibrium Temperatures vs. Radii")
axes[0].grid(axis='y')

# Scatter plot
axes[1].scatter(semi_major_axes, orbital_periods, color='r', marker='o', edgecolors='black', s=100, alpha=0.7)
axes[1].set_xlabel("Semi-Major Axes (megameters)")
axes[1].set_ylabel("Orbital Periods (years)")
axes[1].set_title("Orbital Periods of Exoplanets")
axes[1].grid(True)

plt.tight_layout
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
from orbital_period_finder import orbital_period as obf
period = obf(7)
print(period)
# Out:
# 18.520259177452132
